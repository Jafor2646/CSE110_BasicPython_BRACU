# %%
string = "CSE110"
index = 0
# print(string[0])# third bracket e indexing 0 theika shuru hoy
# print(len(string)) # len function dia string e total koyta character dekha jay
# print(string[len(string)-1]) # total index len er thieka 1 kom tai last character bair korte len()-1
# print(string[-4])#eta negative indexing
while index < len(string):
  print(index, string[index])
  index += 1
# Out:
# 0 C
# 1 S
# 2 E
# 3 1
# 4 1
# 5 0

# %%
string = "CSE110 MIDTERM"
index = 0
while index < len(string):
  if string[index] == " ":
    break
  print(index, string[index])
  index += 1
# Out:
# 0 C
# 1 S
# 2 E
# 3 1
# 4 1
# 5 0

# %%
string = "CSE110 "
# for c in string:
#   print(c)
string2 = "Midterm"
sum = string + " " + string2
print(sum)
s = string*4
print(s,end="  ")
# Out:
# CSE110  Midterm
# CSE110 CSE110 CSE110 CSE110

# %%
string = "CSE110 Midterm"
print(string[0:3])#string slicing
print(string[7:len(string)])
print(string[ : ])
print("CSE" in string)
print("cse" in string)
# Out:
# CSE
# Midterm
# CSE110 Midterm
# True
# False

# %%
#ascii value
s = "CSE110 MIDTERM"
for x in s:
  print(x, ord(x))
print(ord("0"))
print(chr(89))
print(ord("z"))

# %%
#Question: from given input print the small letter only
s = "this is CSE110"

for x in s:
  if ord(x) >= 97 and ord(x) <= 122:
    print(x,end=" ")
print(" ")
#split
s = "sdffksafkfsfkjjsdfcvv"
print(s.split("f"))
# Out:
# t h i s i s
# ['sd', '', 'ksa', 'k', 's', 'kjjsd', 'cvv']
