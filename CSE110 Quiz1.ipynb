# %%
x=int(input("Enter: "))
end=int(input("Enter: "))
main=[]
original=[]
third=[]
for i in range(1,end+1):
    if(i%x==0):
        original.append(i)
for i in range (1,len(original)):
    if(i%3==0):
        third.append(original[i-1])
temp=0
for i in third:
    temp+=i
print("The Original series: ",end="")
for i in range (0,len(original)):
    if(i==len(original)-1):
        print(original[i])
    else:
        print(original[i],end=",")
print("Numbers in every 3rd position: ",end="")
for i in range(0,len(third)):
    if(i==len(third)-1):
        print(third[i])
    else:
        print(third[i],end=",")  
print("Sum of every 3rd position",temp)
# Out:
# Enter: 4
# Enter: 28
# The Original series: 4,8,12,16,20,24,28
# Numbers in every 3rd position: 12,24
# Sum of every 3rd position 36

# %%
x=int(input("Enter: "))
end=int(input("Enter: "))
count = 0
s = ""
if x == 0 or end <= x:
  print("Invalid input")
else:
  print("The Original series: ",end="")
  for i in range(1,end+1):
    if i % x == 0:
      s += str(i) + ","
      #if i == end:
        # print(i)
      #else 
        # print(i,end=",")
  print(s[0:-1])
  s = ""
  print("Numbers in every 3rd position: ",end="")
  for i in range(1,end+1):
    if i % x == 0 and i % 3 == 0:
      s += str(i) + ","
      # if i == end:
      #   print(i)
      # else:
      #   print(i,end=",") 
      count += i
  print(s[0:-1])
  print("Sum of every 3rd position:",count)
# Out:
# Enter: 7
# Enter: 100
# The Original series: 7,14,21,28,35,42,49,56,63,70,77,84,91,98
# Numbers in every 3rd position: 21,42,63,84
# Sum of every 3rd position: 210
